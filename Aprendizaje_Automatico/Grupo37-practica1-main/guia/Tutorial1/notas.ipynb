# %%
from sys import path
import os
path.append(os.path.realpath('../'))


x = 2
print(x)
# Out:
# 2

# %%
# Filtrar datos
# Filtrar filas
df_filtered = df[df['columna'] > 10]

# Agregar columna
df['nueva_columna'] = df['columna1'] + df['columna2']

# Eliminar columna
df = df.drop('columna', axis=1)

# Renombrar columna
df = df.rename(columns={'columna_antigua': 'columna_nueva'})

# %% [markdown]
# Hola que tal estas????

# %%
y = "hola mundo"
print(y)
# Out:
# hola mundo

# %%
import pandas as pd
import seaborn as sns
datos = pd.DataFrame({"manzanas":[3, 2], "peras" :  [1, 4]}, index=["Pepe","Antonio"])
datos
# Out:
#          manzanas  peras
# Pepe            3      1
# Antonio         2      4

# %%
datos.plot.bar()
datos.plot.area()
# Out:
# <Axes: >
